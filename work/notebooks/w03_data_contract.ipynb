# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# # 1. Unit of Analysis + Time Window
#
# **Unit of analysis:** One row represents one page for one day.
#
# **Time window:** March 2026 (2026-03).
#
# The goal is to analyze page-level search performance during this month to support ranking and optimization decisions.

# %%
import pandas as pd

# Load your data (adjust this if the starter notebook loads it differently)
df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))

if "date" in df.columns:
    print("Date range:")
    print(df["date"].min(), "to", df["date"].max())
else:
    print("No date column found.")

df.head()
# Out:
# Rows: 30000
# No date column found.
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# # 2. Fields
#
# ### Features
# - Clicks
# - Impressions
# - CTR
# - Position
# - Word Count
#
# ### Label
# Search performance score (or the chosen prediction target).
#
# ### Context
# Date, page information, and content characteristics.
#
# ### Excluded
# Future clicks and future impressions because they would introduce data leakage.

# %%
print("Columns in dataset:")
print(df.columns.tolist())
# Out:
# Columns in dataset:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# # 3. Verification
#
# The following code verifies:
# - Dataset grain
# - Row count
# - Missing values
# - Date range

# %%
print("Dataset Shape")
print(df.shape)

print("\nMissing Values")
print(df.isnull().sum())

if "date" in df.columns:
    print("\nDate Range")
    print(df["date"].min())
    print(df["date"].max())
# Out:
# Dataset Shape
# (30000, 44)
#
# Missing Values
# content_id                    0
# client_id                     0
# search_volume              2468
# competition                2468
# competition_level          2610
# cpc                        2468
# content_type                  0
# main_intent                2374
# word_count                 7699
# char_count                 7699
# provider_used             21438
# model_used                 5733
# impressions_90d               0
# clicks_90d                    0
# pageviews_90d                 0
# sessions_90d                  0
# users_90d                     0
# engaged_sessions_90d          0
# ai_sessions_90d               0
# scroll_events_90d             0
# days_with_impressions         0
# days_with_sessions            0
# impressions_last_30d          0
# clicks_last_30d               0
# sessions_last_30d             0
# impressions_prev_30d          0
# clicks_prev_30d               0
# ...

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# # 4. Data Limits
#
# This dataset cannot prove causation.
#
# It is anonymized and does not include every search ranking factor.
#
# The analysis provides decision support based on observed historical data only.

# %%
print("Limitations")
print("- Historical data only")
print("- Anonymized dataset")
print("- No causal conclusions")
# Out:
# Limitations
# - Historical data only
# - Anonymized dataset
# - No causal conclusions

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
