# %% [markdown]
# # FL-01: AI Workflow Audit and Tool Setup
#
# **Name:** Mohd Vasi Saifi
#
# **Track:** General AI Fluency
#
# **Week:** 1

# %% [markdown]
# ## 1. My Weekly Tasks

# %%
import pandas as pd

tasks = {
    "Task": [
        "Attend college classes",
        "Study AI/ML",
        "Complete internship assignments",
        "Practice Python",
        "Read documentation",
        "Take notes",
        "Build projects",
        "Debug code",
        "Prepare resume",
        "Apply for internships",
        "Watch AI tutorials",
        "GitHub updates"
    ],

    "Classification": [
        "Just Me",
        "Collaborate with AI",
        "Collaborate with AI",
        "Collaborate with AI",
        "Delegate to AI with Review",
        "Delegate to AI with Review",
        "Collaborate with AI",
        "Collaborate with AI",
        "Delegate to AI with Review",
        "Delegate to AI with Review",
        "Delegate to AI with Review",
        "Just Me"
    ]
}

df = pd.DataFrame(tasks)
df
# Out:
#                                Task              Classification
# 0            Attend college classes                     Just Me
# 1                       Study AI/ML         Collaborate with AI
# 2   Complete internship assignments         Collaborate with AI
# 3                   Practice Python         Collaborate with AI
# 4                Read documentation  Delegate to AI with Review
# 5                        Take notes  Delegate to AI with Review
# 6                    Build projects         Collaborate with AI
# 7                        Debug code         Collaborate with AI
# 8                    Prepare resume  Delegate to AI with Review
# 9             Apply for internships  Delegate to AI with Review
# 10               Watch AI tutorials  Delegate to AI with Review
# 11                   GitHub updates                     Just Me

# %% [markdown]
# ## 2. Tool Setup
#
# - ChatGPT Account ✔
# - Claude Account ✔
# - Anthropic Academy ✔

# %% [markdown]
# ## 3. Claude Project
#
# Project Name:
# AI Internship
#
# Instructions:
#
# - Help with Python
# - Help with Machine Learning
# - Explain concepts simply
# - Use professional tone

# %% [markdown]
# ## 4. Three Reusable Tasks
#
# ### Task 1
# Complete internship notebooks
#
# Success:
# Notebook runs without errors.
#
# ### Task 2
# Debug Python code
#
# Success:
# No syntax errors.
#
# ### Task 3
# Explain ML concepts
#
# Success:
# Simple explanations with examples.

# %% [markdown]
# # Conclusion
#
# This workflow audit identifies where AI can assist and where manual work is still required.
